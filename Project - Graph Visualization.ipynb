# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.subplots(figsize=(10,8))
plt.rcParams.update({"font.size":10})
sns.heatmap(df.corr(),annot=True)
df=pd.read_csv("forestfires.csv")
df.head(10)
# Out:
#    X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.0
# 5  8  6   aug  sun  92.3   85.3  488.0  14.7  22.2  29   5.4   0.0   0.0
# 6  8  6   aug  mon  92.3   88.9  495.6   8.5  24.1  27   3.1   0.0   0.0
# 7  8  6   aug  mon  91.5  145.4  608.2  10.7   8.0  86   2.2   0.0   0.0
# 8  8  6   sep  tue  91.0  129.5  692.6   7.0  13.1  63   5.4   0.0   0.0
# 9  7  5   sep  sat  92.5   88.0  698.6   7.1  22.8  40   4.0   0.0   0.0

# %%
list1=[0 for i in range(517)]
count=0
for index,rows in df.iterrows():
    if rows["area"]==0:
        list1[index]=0
    else:
        list1[index]=1
area_b=pd.DataFrame(list1)
df=pd.concat([df,area_b],axis=1)
df.rename({0:"area_b"},axis=1,inplace=True)
df.drop(["area"],axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le_Gender=LabelEncoder()
#adding the le_gender column to the input var df(x)
df["month_b"]=le_Gender.fit_transform(df["month"])
df["day_b"]=le_Gender.fit_transform(df["day"])
df.drop(["month","day"],axis=1,inplace=True)

# %%
#sns.heatmap(df.corr(),annot=True)
df.head()
# Out:
#    X  Y  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area_b  month_b  day_b
# 0  7  5  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0       0        7      0
# 1  7  4  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0       0       10      5
# 2  7  4  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0       0       10      2
# 3  8  6  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2       0        7      0
# 4  8  6  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0       0        7      3

# %%
plt.subplots(figsize=(20,8))
#sns.heatmap(df.corr(),annot=True)
sns.countplot(x="RH",data=df)

# %%
plt.subplots(figsize=(10,8))
sns.countplot(x="X",data=df)

# %%
plt.subplots(figsize=(10,8))
sns.countplot(x="Y",data=df)

# %%
sns.countplot(x="month_b",data=df)

# %%
plt.subplots(figsize=(10,8))
sns.distplot(df["X"])

# %%
plt.subplots(figsize=(10,8))
sns.distplot(df["RH"])

# %%
plt.subplots(figsize=(10,8))
sns.countplot(x="day_b",data=df)

# %%
plt.subplots(figsize=(28,15))
sns.countplot(x="FFMC",data=df)

# %%
#plt.subplots(figsize=(50,20))
sns.countplot(x="DMC",data=df)

# %%
#plt.subplots(figsize=(28,15))
sns.countplot(x="DC",data=df)

# %%
plt.subplots(figsize=(28,15))
#plt.rcParams.update({"font.size":25})
sns.countplot(x="ISI",data=df)

# %%
#plt.subplots(figsize=(28,15))

sns.countplot(x="temp",data=df)

# %%
plt.subplots(figsize=(10,8))
sns.countplot(x="wind",data=df)

# %%
sns.countplot(x="rain",data=df)

# %%
sns.countplot(x="area_b",data=df)

# %%
sns.distplot(df["Y"])

# %%
sns.distplot(df["FFMC"])

# %%
sns.distplot(df["DMC"])

# %%
sns.distplot(df["DC"])

# %%
sns.distplot(df["ISI"])

# %%
sns.distplot(df["temp"])

# %%
sns.distplot(df["wind"])

# %%
sns.distplot(df["rain"])

# %%
sns.distplot(df["area_b"])

# %%
sns.distplot(df["month_b"])

# %%
sns.distplot(df["day_b"])

# %%
plt.boxplot(df["Y"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1afd796ea90>,
#   <matplotlib.lines.Line2D at 0x1afd796edd8>],
#  'caps': [<matplotlib.lines.Line2D at 0x1afd796eeb8>,
#   <matplotlib.lines.Line2D at 0x1afd79784a8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1afd796e668>],
#  'medians': [<matplotlib.lines.Line2D at 0x1afd79787f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1afd7978b38>],
#  'means': []}

# %%
#removing outleirs of Y
count=0
for index,row in df.iterrows():
    if (row["Y"]>6) or (row["Y"]<3) :
        df=df.drop(index)
        count+=1
print(df["Y"].count())
plt.boxplot(df["Y"])
df.info()
print(count)
# Out:
# 466
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 466 entries, 0 to 516
# Data columns (total 13 columns):
# X          466 non-null int64
# Y          466 non-null int64
# FFMC       466 non-null float64
# DMC        466 non-null float64
# DC         466 non-null float64
# ISI        466 non-null float64
# temp       466 non-null float64
# RH         466 non-null int64
# wind       466 non-null float64
# rain       466 non-null float64
# area_b     466 non-null int64
# month_b    466 non-null int32
# day_b      466 non-null int32
# dtypes: float64(7), int32(2), int64(4)
# memory usage: 47.3 KB
# 51

# %%
#removing outleirs of Y
count=0
for index,row in df.iterrows():
    if (row["X"]>6) or (row["X"]<3) :
        df=df.drop(index)
        count+=1
print(df["X"].count())
plt.boxplot(df["X"])
df.info()
print(count)
# Out:
# 262
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 262 entries, 12 to 516
# Data columns (total 13 columns):
# X          262 non-null int64
# Y          262 non-null int64
# FFMC       262 non-null float64
# DMC        262 non-null float64
# DC         262 non-null float64
# ISI        262 non-null float64
# temp       262 non-null float64
# RH         262 non-null int64
# wind       262 non-null float64
# rain       262 non-null float64
# area_b     262 non-null int64
# month_b    262 non-null int32
# day_b      262 non-null int32
# dtypes: float64(7), int32(2), int64(4)
# memory usage: 26.6 KB
# 204
