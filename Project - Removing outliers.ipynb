# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("forestfires.csv")
df.head(10)

list1=[0 for i in range(517)]
count=0
for index,rows in df.iterrows():
    if rows["area"]==0:
        list1[index]=0
    else:
        list1[index]=1
area_b=pd.DataFrame(list1)
df=pd.concat([df,area_b],axis=1)
df.rename({0:"area_b"},axis=1,inplace=True)
df.drop(["area"],axis=1,inplace=True)

from sklearn.preprocessing import LabelEncoder
le_Gender=LabelEncoder()
#adding the le_gender column to the input var df(x)
df["month_b"]=le_Gender.fit_transform(df["month"])
df["day_b"]=le_Gender.fit_transform(df["day"])
df.drop(["month","day"],axis=1,inplace=True)

# %%
sns.heatmap(df.corr(),annot=True)

# %%
plt.boxplot(df["Y"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16533271780>,
#   <matplotlib.lines.Line2D at 0x16533271ac8>],
#  'caps': [<matplotlib.lines.Line2D at 0x16533271e10>,
#   <matplotlib.lines.Line2D at 0x16533271ef0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x16533271358>],
#  'medians': [<matplotlib.lines.Line2D at 0x1653328b4e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1653328b828>],
#  'means': []}

# %%
#removing outleirs of Y
count=0
for index,row in df.iterrows():
    if (row["Y"]>6) or (row["Y"]<3) :
        df=df.drop(index)
        count+=1
print(df["Y"].count())
plt.boxplot(df["Y"])
df.info()
print(count)
# Out:
# 466
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 466 entries, 0 to 516
# Data columns (total 13 columns):
# X          466 non-null int64
# Y          466 non-null int64
# FFMC       466 non-null float64
# DMC        466 non-null float64
# DC         466 non-null float64
# ISI        466 non-null float64
# temp       466 non-null float64
# RH         466 non-null int64
# wind       466 non-null float64
# rain       466 non-null float64
# area_b     466 non-null int64
# month_b    466 non-null int32
# day_b      466 non-null int32
# dtypes: float64(7), int32(2), int64(4)
# memory usage: 47.3 KB
# 51

# %%
plt.boxplot(df["X"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x165333509e8>,
#   <matplotlib.lines.Line2D at 0x16533350d30>],
#  'caps': [<matplotlib.lines.Line2D at 0x16533350e10>,
#   <matplotlib.lines.Line2D at 0x1653335c400>],
#  'boxes': [<matplotlib.lines.Line2D at 0x165333505c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1653335c748>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1653335ca90>],
#  'means': []}

# %%
plt.boxplot(df["FFMC"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x165333adc50>,
#   <matplotlib.lines.Line2D at 0x165333adf98>],
#  'caps': [<matplotlib.lines.Line2D at 0x165333b6320>,
#   <matplotlib.lines.Line2D at 0x165333b6668>],
#  'boxes': [<matplotlib.lines.Line2D at 0x165333ad828>],
#  'medians': [<matplotlib.lines.Line2D at 0x165333b69b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x165333b6cf8>],
#  'means': []}

# %%
#removing outleirs of FFMC
count=0
for index,row in df.iterrows():
    if (row["FFMC"]>96) or (row["FFMC"]<88) :
        df=df.drop(index)
        count+=1
print(df["FFMC"].count())
plt.boxplot(df["FFMC"])
df.info()
print(count)
# Out:
# 393
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 393 entries, 1 to 515
# Data columns (total 13 columns):
# X          393 non-null int64
# Y          393 non-null int64
# FFMC       393 non-null float64
# DMC        393 non-null float64
# DC         393 non-null float64
# ISI        393 non-null float64
# temp       393 non-null float64
# RH         393 non-null int64
# wind       393 non-null float64
# rain       393 non-null float64
# area_b     393 non-null int64
# month_b    393 non-null int32
# day_b      393 non-null int32
# dtypes: float64(7), int32(2), int64(4)
# memory usage: 39.9 KB
# 73

# %%
plt.boxplot(df["DMC"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1653346ec50>,
#   <matplotlib.lines.Line2D at 0x1653346ef98>],
#  'caps': [<matplotlib.lines.Line2D at 0x16533478320>,
#   <matplotlib.lines.Line2D at 0x16533478668>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1653346e828>],
#  'medians': [<matplotlib.lines.Line2D at 0x165334789b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16533478cf8>],
#  'means': []}

# %%
#removing outleirs of DMC
count=0
for index,row in df.iterrows():
    if (row["DMC"]>215) or (row["DMC"]<5) :
        df=df.drop(index)
        count+=1
print(df["DMC"].count())
plt.boxplot(df["DMC"])
df.info()
print(count)
# Out:
# 355
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 355 entries, 1 to 515
# Data columns (total 13 columns):
# X          355 non-null int64
# Y          355 non-null int64
# FFMC       355 non-null float64
# DMC        355 non-null float64
# DC         355 non-null float64
# ISI        355 non-null float64
# temp       355 non-null float64
# RH         355 non-null int64
# wind       355 non-null float64
# rain       355 non-null float64
# area_b     355 non-null int64
# month_b    355 non-null int32
# day_b      355 non-null int32
# dtypes: float64(7), int32(2), int64(4)
# memory usage: 36.1 KB
# 38

# %%
plt.boxplot(df["DC"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x165344f8320>,
#   <matplotlib.lines.Line2D at 0x165344f8668>],
#  'caps': [<matplotlib.lines.Line2D at 0x165344f89b0>,
#   <matplotlib.lines.Line2D at 0x165344f8cf8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1653351feb8>],
#  'medians': [<matplotlib.lines.Line2D at 0x165344f8dd8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x165345033c8>],
#  'means': []}

# %%
#removing outleirs of DC
count=0
for index,row in df.iterrows():
    if (row["DC"]>800) or (row["DC"]<450) :
        df=df.drop(index)
        count+=1
print(df["DC"].count())
plt.boxplot(df["DC"])
df.info()
print(count)
# Out:
# 275
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 275 entries, 1 to 515
# Data columns (total 13 columns):
# X          275 non-null int64
# Y          275 non-null int64
# FFMC       275 non-null float64
# DMC        275 non-null float64
# DC         275 non-null float64
# ISI        275 non-null float64
# temp       275 non-null float64
# RH         275 non-null int64
# wind       275 non-null float64
# rain       275 non-null float64
# area_b     275 non-null int64
# month_b    275 non-null int32
# day_b      275 non-null int32
# dtypes: float64(7), int32(2), int64(4)
# memory usage: 27.9 KB
# 80

# %%
plt.boxplot(df["ISI"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x165345afe80>,
#   <matplotlib.lines.Line2D at 0x165345aff60>],
#  'caps': [<matplotlib.lines.Line2D at 0x165345ba550>,
#   <matplotlib.lines.Line2D at 0x165345ba898>],
#  'boxes': [<matplotlib.lines.Line2D at 0x165345afa58>],
#  'medians': [<matplotlib.lines.Line2D at 0x165345babe0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x165345baf28>],
#  'means': []}

# %%
#removing outleirs of ISI
count=0
for index,row in df.iterrows():
    if (row["ISI"]>15.5) or (row["ISI"]<0) :
        df=df.drop(index)
        count+=1
print(df["ISI"].count())
plt.boxplot(df["ISI"])
df.info()
print(count)
# Out:
# 247
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 247 entries, 1 to 515
# Data columns (total 13 columns):
# X          247 non-null int64
# Y          247 non-null int64
# FFMC       247 non-null float64
# DMC        247 non-null float64
# DC         247 non-null float64
# ISI        247 non-null float64
# temp       247 non-null float64
# RH         247 non-null int64
# wind       247 non-null float64
# rain       247 non-null float64
# area_b     247 non-null int64
# month_b    247 non-null int32
# day_b      247 non-null int32
# dtypes: float64(7), int32(2), int64(4)
# memory usage: 25.1 KB
# 28

# %%
plt.boxplot(df["temp"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16534662dd8>,
#   <matplotlib.lines.Line2D at 0x1653466e400>],
#  'caps': [<matplotlib.lines.Line2D at 0x1653466e748>,
#   <matplotlib.lines.Line2D at 0x1653466ea90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x16534662c88>],
#  'medians': [<matplotlib.lines.Line2D at 0x1653466edd8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1653466eeb8>],
#  'means': []}

# %%
#removing outleirs of temp
count=0
for index,row in df.iterrows():
    if (row["temp"]>30) or (row["temp"]<12) :
        df=df.drop(index)
        count+=1
print(df["temp"].count())
plt.boxplot(df["temp"])
df.info()
print(count)
# Out:
# 230
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 230 entries, 1 to 515
# Data columns (total 13 columns):
# X          230 non-null int64
# Y          230 non-null int64
# FFMC       230 non-null float64
# DMC        230 non-null float64
# DC         230 non-null float64
# ISI        230 non-null float64
# temp       230 non-null float64
# RH         230 non-null int64
# wind       230 non-null float64
# rain       230 non-null float64
# area_b     230 non-null int64
# month_b    230 non-null int32
# day_b      230 non-null int32
# dtypes: float64(7), int32(2), int64(4)
# memory usage: 23.4 KB
# 17

# %%
plt.boxplot(df["RH"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1653471b470>,
#   <matplotlib.lines.Line2D at 0x1653471b7b8>],
#  'caps': [<matplotlib.lines.Line2D at 0x1653471bb00>,
#   <matplotlib.lines.Line2D at 0x1653471be48>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1653471b048>],
#  'medians': [<matplotlib.lines.Line2D at 0x1653471bf28>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16534724518>],
#  'means': []}

# %%
plt.boxplot(df["wind"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1653476acc0>,
#   <matplotlib.lines.Line2D at 0x1653476ada0>],
#  'caps': [<matplotlib.lines.Line2D at 0x16534775390>,
#   <matplotlib.lines.Line2D at 0x165347756d8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1653476a898>],
#  'medians': [<matplotlib.lines.Line2D at 0x16534775a20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16534775d68>],
#  'means': []}

# %%
plt.boxplot(df["rain"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16534692588>,
#   <matplotlib.lines.Line2D at 0x16534692e10>],
#  'caps': [<matplotlib.lines.Line2D at 0x16534692898>,
#   <matplotlib.lines.Line2D at 0x16534686390>],
#  'boxes': [<matplotlib.lines.Line2D at 0x165346929b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x16534686400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x165346863c8>],
#  'means': []}

# %%
#after seeing so many outliers in rain, dropping rain
df.drop(["rain"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    X  Y  FFMC    DMC     DC   ISI  temp  RH  wind  area_b  month_b  day_b
# 1  7  4  90.6   35.4  669.1   6.7  18.0  33   0.9       0       10      5
# 2  7  4  90.6   43.7  686.9   6.7  14.6  33   1.3       0       10      2
# 5  8  6  92.3   85.3  488.0  14.7  22.2  29   5.4       0        1      3
# 6  8  6  92.3   88.9  495.6   8.5  24.1  27   3.1       0        1      1
# 8  8  6  91.0  129.5  692.6   7.0  13.1  63   5.4       0       11      5

# %%
plt.boxplot(df["month_b"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1653452a1d0>,
#   <matplotlib.lines.Line2D at 0x1653452ac18>],
#  'caps': [<matplotlib.lines.Line2D at 0x16534535240>,
#   <matplotlib.lines.Line2D at 0x16534535668>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1653452a940>],
#  'medians': [<matplotlib.lines.Line2D at 0x165345350b8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16534535f28>],
#  'means': []}

# %%
plt.boxplot(df["day_b"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16533430748>,
#   <matplotlib.lines.Line2D at 0x16533430320>],
#  'caps': [<matplotlib.lines.Line2D at 0x16533430588>,
#   <matplotlib.lines.Line2D at 0x165334307b8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x165333dd978>],
#  'medians': [<matplotlib.lines.Line2D at 0x16533430630>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16533437c50>],
#  'means': []}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 230 entries, 1 to 515
# Data columns (total 12 columns):
# X          230 non-null int64
# Y          230 non-null int64
# FFMC       230 non-null float64
# DMC        230 non-null float64
# DC         230 non-null float64
# ISI        230 non-null float64
# temp       230 non-null float64
# RH         230 non-null int64
# wind       230 non-null float64
# area_b     230 non-null int64
# month_b    230 non-null int32
# day_b      230 non-null int32
# dtypes: float64(6), int32(2), int64(4)
# memory usage: 21.6 KB

# %%
sns.countplot(x="area_b",data=df)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
x=df.drop("area_b",axis=1)
y=df["area_b"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100)
logmodel=LogisticRegression()
logmodel.fit(x_train,y_train)

y_pred=logmodel.predict(x_test)
#print(x_test)
#print(y_pred)
#print(y_test)
#print(y_pred[270],y_test[270])
# Out:
# C:\Users\Prabal\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.6231884057971014

# %%
sns.heatmap(df.corr(),annot=True)

# %%
#after removing outliers from all columns, the corr of FFMC and day_b decrease wrt area_b and rest is increasing.
#5% accuracy increased  using logistic regression.
